# %%
from utils import load_sunrgbd_dataset
from utils import EarlyStopping
from networks import SegNet
from utils import get_data_loader
from utils import ConfMatrix
from training import train_model
from training import train_loop
from utils import draw_training_curves
from training import run_inference

BATCH_SIZE = 16

# %%
data, label = load_sunrgbd_dataset()

train_loader = get_data_loader('segmentation', data, label, "train", BATCH_SIZE)
val_loader = get_data_loader('segmentation', data, label, "val", BATCH_SIZE)
test_loader = get_data_loader('segmentation', data, label, "test", BATCH_SIZE)

# train model
losses, accuracies, model, flag = train_model('segmentation', train_loader, val_loader)

# plot trained metrics
loss_curve = "loss"
draw_training_curves(losses[0], losses[1],loss_curve)
loss_curve = "accuracy"
draw_training_curves(accuracies[0], accuracies[1],loss_curve)

run_inference('segmentation', model, test_loader)
# Out:
# Running Epoch 1
# Training loss: 2.7978   Training accuracy: 0.0738   Training mIoU: 0.0278
# Validation loss: 2.6286 Validation accuracy: 0.0876 Validation mIoU: 0.0154
# --------------------------------------------------------
# Running Epoch 2
# Training loss: 2.6056   Training accuracy: 0.1425   Training mIoU: 0.0425
# Validation loss: 2.6081 Validation accuracy: 0.1300 Validation mIoU: 0.0218
# --------------------------------------------------------
# Training completed!
# Mean Pixel IoU:  0.023874085396528244
# Accuracy:  0.1456315964460373
# Final loss on test images:  2.602635837974349
